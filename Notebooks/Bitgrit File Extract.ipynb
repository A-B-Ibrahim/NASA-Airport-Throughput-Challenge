# %%
import zipfile as zf
import os

# %%
def unzip_data(zip_dir, new_dir, end):
    """
    Function extracts all files of interest from [multiple] zip files that have nested directories (zipped or otherwise) within them.
    Made for windows os.
    This function assumes that all zipped directories of interest of been placed inside an non-zipped directory and the path of that directory is known (this is what the zip_dir variable represents).
    This function only removes the end file type of interest - specified by end variable - by itself; it does not preserve the structure of directories it my belong to (file is taken out of place).
    Any directory [path] can be choosen as new_dir and this is where the extracted files will all be moved to. 
    Be carefull of running function multiple times as it does not check if files extracted already exist in the new directory; watch out for duplicates.
    
    The inputs are the path to the directory the zipped direcotries are in (old_dir); path to the directory you wish to put the files in (new_dir); and the file type (end), specified by the '.[blank]' at the end of the file.
    The output will be the movement of the files of interest to the selected directory (new_dir).
    """
    
    print(f'unzipping folders in {zip_dir}') #display zipped directories that the files of interest will be extracted from 
    #open zipped directory
    files = os.listdir(zip_dir) #get all file names within the an unzipped directory
    for file in files:
        if file.endswith('.zip'): #error handling to ensure only zip files are attempting to be unzipped (from within the unzipped directory)
            file_path = os.path.join(zip_dir, file) #create the path used for opening the unzipped directories
            #unzip directory
            #derivative of Gerhard Götz's answer at https://stackoverflow.com/questions/4917284/extract-files-from-zip-without-keeping-the-structure-using-python-zipfile
            with zf.ZipFile(file_path) as zip_folder:
                for zip_info in zip_folder.infolist(): 
                    #handle nested zip folders
                    if '.zip' in zip_info.filename: #detect if directory is zip or not
                        print(zip_info.filename) #tell user what file is being looked at
                        temp = os.path.join(zip_dir,'temp') #open a temperary directory to store all zipped directory
                        zip_folder.extractall(temp) #move all nested zip folders to temp directory
                        unzip_data(temp,new_dir,end) #repeat process with nested zip folders (call same function using the path leading to temp dir that has the [originally] nested folders)
                        
                        #attempt to delete temp directory path as it is no longer needed 
                        #original code from https://stackoverflow.com/questions/6996603/how-can-i-delete-a-file-or-folder-in-python by Anand Tripathi
                        try:
                            os.remove(new_dir)
                        except OSError as e:
                            # If it fails, inform the user.
                            print("Error: %s - %s." % (e.filename, e.strerror))
                        #end of borrowed code
                        
                        break #further steps have already been run when the function was recalled; prevent them from being re-ran
                    #take data from unzipped directories
                    else:
                        #only lookes at files and not other directories. We only want to take files from directories not directories from other directories
                        if zip_info.is_dir():
                            continue #skips files that fall under this condition
                        #ensures that we are only extracting the files type we want from the directory; 'end' referes to the file the .[blank] at the end of a file (specified when calling function)
                        elif zip_info.filename.endswith(end) != True:
                            continue #skips files that fall under this condition
                        #prevents the extraction of files formated for MAC OS (as this is being run on a windows PC)
                        elif '_MACOSX' in zip_info.filename: #can change to "elif '_MACOSX' not in zip_info.filename:" if running on MAC
                            continue #skips files that fall under this condition
                        #extracts only the files of interest from directory and puts them in a new directory (specified when calling function)
                        else:
                            print(zip_info.filename) #tell user what file is being extracted
                            zip_info.filename = os.path.basename(zip_info.filename) #makes it so we ONLY get the end file (out of place) and not the directories that it was in as well (in place)
                            zip_folder.extract(zip_info, new_dir) #put files into designated new directory
            #end of derivative 
        #connected to the if statement about only extracting zip files from original directory path; skips over them
        else: 
            continue #skips files that fall under this condition

# %%
CWAM_pathway = #pathway to directory where CWAM folders downloaded from bitgrit NASA challenge where stored
new_CWAM_dir = #pathway to directory you want extracted CWAM files to be placed in
CWAM_file_ending = '.bz2'
"""
Expected CWAM pathway:
    non-zipped DIR (CWAM_pathway)
    -zip dir 1 (download from bitgrit challenge)
        --_MACOSX
        --Dir with YYMMDD_YYMMDD name representing the time window it refers to
            ---Dir with MM name representing the month it refers to no. 1
                ----Dir with DD name representing the day it refers to no. 1
                    -----Dir with full datatime of forecast name no. 1
                        ------.bz2 file with data for datetime
                        
                    -----Dir with full datetime of forecast name no. 2
                    -----Dir with full datetime of forecast name etc.
                ----Dir with DD name no. 2
                ----Dir with DD name etc.
            ---Dir with MM name no. 2
            ---Dir with MM name etc.
            ---.DS_Store
    -zip dir 2 (download from bitgrit challenge)
    -zip dir 3 (download from bitgrit challenge)
    -zip dir etc. (download from bitgrit challenge)
"""

FUSAR_pathway = #pathway to directory where FUSAR folders downloaded from bitgrit NASA challenge where stored
new_FUSAR_dir = #pathway to directory you want extracted FUSAR files to be placed in
FUSAR_file_ending = '.csv'
"""
Expected FUSAR pathway:
    non-zipped DIR (FUSAR_pathway)
    -zip dir 1 (download from bitgrit challenge)
        --_MACOSX
        --Dir with Airport ICAO as name
            ---.csv file of fusar data no. 1
            
            ---.csv file of fusar data no. 2
            ---.csv file of fusar data etc.
            ---.DS_Store
    -zip dir 2 (download from bitgrit challenge)
    -zip dir 3 (download from bitgrit challenge)
    -zip dir etc. (download from bitgrit challenge)
"""

METAR_pathway = #pathway to directory where METAR folders downloaded from bitgrit NASA challenge where stored
new_METAR_dir = #pathway to directory you want extracted METAR files to be placed in
METAR_file_ending = '.txt'
"""
Expected METAR pathway:
    non-zipped DIR (METAR_pathway)
    -zip dir (download from bitgrit challenge)
        --nested zip dir no. 1
            ---_MACOSX
            ---Dir named METAR_train_part_[#]
                ---.txt file with METAR data for a timestamp no. 1
                ---.txt file with METAR data for a timestamp no. 2
                ---.txt file with METAR data for a timestamp etc.
            
        --nested zip dir no. 2
        --nested zip dir etc.
"""

TAF_pathway = #pathway to directory where TAF folders downloaded from bitgrit NASA challenge where stored
new_TAF_dir = #pathway to directory you want extracted TAF files to be placed in
TAF_file_ending = '.txt'
"""
Expected TAF pathway:
    non-zipped DIR (TAF_pathway)
    -zipped dir (download from bitgrit challenge)
        --_MACOSX
        --dir named TAF_train
            ---.txt file of TAF data for a timestamp no. 1
            ---.txt file of TAF data for a timestamp no. 2
            ---.txt file of TAF data for a timestamp no. etc.
"""

#METAR
unzip_data(METAR_pathway,new_METAR_dir,METAR_file_ending) 
#FUSAR
unzip_data(FUSAR_pathway,new_FUSAR_dir,FUSAR_file_ending)
#TAF
unzip_data(TAF_pathway,new_TAF_dir,TAF_file_ending)
#CWAM
unzip_data(CWAM_pathway,new_CWAM_dir,CWAM_file_ending)
# Out:
# unzipping folders in E:\Users\Alex\ENVS\bitgrit Challenge\DATA\METAR\Train
# METAR_train_part_1.zip
# unzipping folders in E:\Users\Alex\ENVS\bitgrit Challenge\DATA\METAR\Train\temp
# METAR_train_part_1/metar.20221023.23Z.txt
# METAR_train_part_1/metar.20220922.14Z.txt
# METAR_train_part_1/metar.20221011.17Z.txt
# METAR_train_part_1/metar.20220910.20Z.txt
# METAR_train_part_1/metar.20220921.04Z.txt
# METAR_train_part_1/metar.20221012.07Z.txt
# METAR_train_part_1/metar.20221015.03Z.txt
# METAR_train_part_1/metar.20221009.20Z.txt
# METAR_train_part_1/metar.20220908.17Z.txt
# METAR_train_part_1/metar.20220916.09Z.txt
# METAR_train_part_1/metar.20220906.09Z.txt
# METAR_train_part_1/metar.20220918.17Z.txt
# METAR_train_part_1/metar.20221019.20Z.txt
# METAR_train_part_1/metar.20221005.03Z.txt
# METAR_train_part_1/metar.20220915.19Z.txt
# METAR_train_part_1/metar.20221016.13Z.txt
# METAR_train_part_1/metar.20221006.13Z.txt
# METAR_train_part_1/metar.20220905.19Z.txt
# METAR_train_part_1/metar.20221005.15Z.txt
# METAR_train_part_1/metar.20220918.01Z.txt
# METAR_train_part_1/metar.20220904.22Z.txt
# METAR_train_part_1/metar.20220914.22Z.txt
# METAR_train_part_1/metar.20220908.01Z.txt
# METAR_train_part_1/metar.20221015.15Z.txt
# METAR_train_part_1/metar.20221006.05Z.txt
# METAR_train_part_1/metar.20221016.05Z.txt
# METAR_train_part_1/metar.20220922.02Z.txt
# METAR_train_part_1/metar.20221021.08Z.txt
# METAR_train_part_1/metar.20221011.01Z.txt
# METAR_train_part_1/metar.20221022.18Z.txt
# METAR_train_part_1/metar.20220921.12Z.txt
# METAR_train_part_1/metar.20221012.11Z.txt
# METAR_train_part_1/metar.20221017.04Z.txt
# METAR_train_part_1/metar.20221007.04Z.txt
# METAR_train_part_1/metar.20220924.07Z.txt
# METAR_train_part_1/metar.20220909.00Z.txt
# METAR_train_part_1/metar.20220915.23Z.txt
# METAR_train_part_1/metar.20221014.14Z.txt
# METAR_train_part_1/metar.20221004.14Z.txt
# METAR_train_part_1/metar.20220905.23Z.txt
# METAR_train_part_1/metar.20220919.00Z.txt
# METAR_train_part_1/metar.20221026.20Z.txt
# METAR_train_part_1/metar.20221013.10Z.txt
# METAR_train_part_1/metar.20221003.10Z.txt
# METAR_train_part_1/metar.20221023.19Z.txt
# METAR_train_part_1/metar.20220920.13Z.txt
# METAR_train_part_1/metar.20221010.00Z.txt
# METAR_train_part_1/metar.20220923.03Z.txt
# METAR_train_part_1/metar.20221020.09Z.txt
# METAR_train_part_1/metar.20221003.06Z.txt
# METAR_train_part_1/metar.20221013.06Z.txt
# METAR_train_part_1/metar.20220920.05Z.txt
# METAR_train_part_1/metar.20220901.21Z.txt
# METAR_train_part_1/metar.20221010.16Z.txt
# METAR_train_part_1/metar.20220911.21Z.txt
# METAR_train_part_1/metar.20221022.22Z.txt
# METAR_train_part_1/metar.20220923.15Z.txt
# METAR_train_part_1/metar.20221007.12Z.txt
# METAR_train_part_1/metar.20220904.18Z.txt
# METAR_train_part_1/metar.20220914.18Z.txt
# METAR_train_part_1/metar.20221017.12Z.txt
# METAR_train_part_1/metar.20220924.11Z.txt
# METAR_train_part_1/metar.20220919.16Z.txt
# METAR_train_part_1/metar.20220907.08Z.txt
# METAR_train_part_1/metar.20221004.02Z.txt
# METAR_train_part_1/metar.20221018.21Z.txt
# METAR_train_part_1/metar.20221008.21Z.txt
# METAR_train_part_1/metar.20221014.02Z.txt
# METAR_train_part_1/metar.20220917.08Z.txt
# METAR_train_part_1/metar.20220909.16Z.txt
# METAR_train_part_1/metar.20221022.02Z.txt
# METAR_train_part_1/metar.20220921.08Z.txt
# METAR_train_part_1/metar.20220901.01Z.txt
# METAR_train_part_1/metar.20220911.01Z.txt
# METAR_train_part_1/metar.20220922.18Z.txt
# METAR_train_part_1/metar.20221021.12Z.txt
# METAR_train_part_1/metar.20220902.11Z.txt
# METAR_train_part_1/metar.20220912.11Z.txt
# METAR_train_part_1/metar.20221026.16Z.txt
# METAR_train_part_1/metar.20220905.15Z.txt
# METAR_train_part_1/metar.20221004.22Z.txt
# METAR_train_part_1/metar.20221018.01Z.txt
# METAR_train_part_1/metar.20221008.01Z.txt
# METAR_train_part_1/metar.20221014.22Z.txt
# METAR_train_part_1/metar.20220915.15Z.txt
# METAR_train_part_1/metar.20221025.06Z.txt
# METAR_train_part_1/metar.20220906.05Z.txt
# METAR_train_part_1/metar.20220916.05Z.txt
# METAR_train_part_1/metar.20221026.00Z.txt
# METAR_train_part_1/metar.20220909.20Z.txt
# METAR_train_part_1/metar.20220915.03Z.txt
# METAR_train_part_1/metar.20221016.09Z.txt
# METAR_train_part_1/metar.20221008.17Z.txt
# METAR_train_part_1/metar.20221018.17Z.txt
# METAR_train_part_1/metar.20221006.09Z.txt
# METAR_train_part_1/metar.20220905.03Z.txt
# METAR_train_part_1/metar.20220919.20Z.txt
# METAR_train_part_1/metar.20221025.10Z.txt
# METAR_train_part_1/metar.20221015.19Z.txt
# METAR_train_part_1/metar.20220916.13Z.txt
# METAR_train_part_1/metar.20220906.13Z.txt
# METAR_train_part_1/metar.20221005.19Z.txt
# METAR_train_part_1/metar.20220923.23Z.txt
# METAR_train_part_1/metar.20221022.14Z.txt
# METAR_train_part_1/metar.20220911.17Z.txt
# METAR_train_part_1/metar.20221010.20Z.txt
# METAR_train_part_1/metar.20220901.17Z.txt
# METAR_train_part_1/metar.20221021.04Z.txt
# METAR_train_part_1/metar.20220912.07Z.txt
# METAR_train_part_1/metar.20220902.07Z.txt
# METAR_train_part_1/metar.20220907.12Z.txt
# METAR_train_part_1/metar.20221004.18Z.txt
# METAR_train_part_1/metar.20221014.18Z.txt
# METAR_train_part_1/metar.20220917.12Z.txt
# METAR_train_part_1/metar.20221024.11Z.txt
# METAR_train_part_1/metar.20221007.08Z.txt
# METAR_train_part_1/metar.20221019.16Z.txt
# METAR_train_part_1/metar.20220918.21Z.txt
# METAR_train_part_1/metar.20220904.02Z.txt
# METAR_train_part_1/metar.20220914.02Z.txt
# METAR_train_part_1/metar.20220908.21Z.txt
# METAR_train_part_1/metar.20221009.16Z.txt
# METAR_train_part_1/metar.20221017.08Z.txt
# METAR_train_part_1/metar.20220903.06Z.txt
# METAR_train_part_1/metar.20220913.06Z.txt
# METAR_train_part_1/metar.20221020.05Z.txt
# METAR_train_part_1/metar.20220910.16Z.txt
# METAR_train_part_1/metar.20221011.21Z.txt
# METAR_train_part_1/metar.20220922.22Z.txt
# METAR_train_part_1/metar.20221023.15Z.txt
# METAR_train_part_1/metar.20220913.10Z.txt
# METAR_train_part_1/metar.20220903.10Z.txt
# METAR_train_part_1/metar.20220923.19Z.txt
# METAR_train_part_1/metar.20221020.13Z.txt
# METAR_train_part_1/metar.20220910.00Z.txt
# METAR_train_part_1/metar.20221023.03Z.txt
# METAR_train_part_1/metar.20220920.09Z.txt
# METAR_train_part_1/metar.20220917.04Z.txt
# METAR_train_part_1/metar.20220907.04Z.txt
# METAR_train_part_1/metar.20221024.07Z.txt
# METAR_train_part_1/metar.20221015.23Z.txt
# METAR_train_part_1/metar.20221009.00Z.txt
# METAR_train_part_1/metar.20220914.14Z.txt
# METAR_train_part_1/metar.20220904.14Z.txt
# METAR_train_part_1/metar.20221019.00Z.txt
# METAR_train_part_1/metar.20221005.23Z.txt
# METAR_train_part_1/metar.20221015.22Z.txt
# METAR_train_part_1/metar.20221009.01Z.txt
# METAR_train_part_1/metar.20220914.15Z.txt
# METAR_train_part_1/metar.20220904.15Z.txt
# METAR_train_part_1/metar.20221019.01Z.txt
# METAR_train_part_1/metar.20221005.22Z.txt
# METAR_train_part_1/metar.20220917.05Z.txt
# METAR_train_part_1/metar.20220907.05Z.txt
# METAR_train_part_1/metar.20221024.06Z.txt
# METAR_train_part_1/metar.20220910.01Z.txt
# METAR_train_part_1/metar.20221023.02Z.txt
# METAR_train_part_1/metar.20220920.08Z.txt
# METAR_train_part_1/metar.20220913.11Z.txt
# METAR_train_part_1/metar.20220903.11Z.txt
# METAR_train_part_1/metar.20220923.18Z.txt
# METAR_train_part_1/metar.20221020.12Z.txt
# METAR_train_part_1/metar.20220910.17Z.txt
# METAR_train_part_1/metar.20221011.20Z.txt
# METAR_train_part_1/metar.20220922.23Z.txt
# METAR_train_part_1/metar.20221023.14Z.txt
# METAR_train_part_1/metar.20220903.07Z.txt
# METAR_train_part_1/metar.20220913.07Z.txt
# METAR_train_part_1/metar.20221020.04Z.txt
# METAR_train_part_1/metar.20221007.09Z.txt
# METAR_train_part_1/metar.20221019.17Z.txt
# METAR_train_part_1/metar.20220918.20Z.txt
# METAR_train_part_1/metar.20220904.03Z.txt
# METAR_train_part_1/metar.20220914.03Z.txt
# METAR_train_part_1/metar.20220908.20Z.txt
# METAR_train_part_1/metar.20221009.17Z.txt
# METAR_train_part_1/metar.20221017.09Z.txt
# METAR_train_part_1/metar.20220907.13Z.txt
# METAR_train_part_1/metar.20221004.19Z.txt
# METAR_train_part_1/metar.20221014.19Z.txt
# METAR_train_part_1/metar.20220917.13Z.txt
# METAR_train_part_1/metar.20221024.10Z.txt
# METAR_train_part_1/metar.20221021.05Z.txt
# METAR_train_part_1/metar.20220912.06Z.txt
# METAR_train_part_1/metar.20220902.06Z.txt
# METAR_train_part_1/metar.20220923.22Z.txt
# METAR_train_part_1/metar.20221022.15Z.txt
# METAR_train_part_1/metar.20220911.16Z.txt
# METAR_train_part_1/metar.20221010.21Z.txt
# METAR_train_part_1/metar.20220901.16Z.txt
# METAR_train_part_1/metar.20221025.11Z.txt
# METAR_train_part_1/metar.20221015.18Z.txt
# METAR_train_part_1/metar.20220916.12Z.txt
# METAR_train_part_1/metar.20220906.12Z.txt
# METAR_train_part_1/metar.20221005.18Z.txt
# METAR_train_part_1/metar.20221026.01Z.txt
# METAR_train_part_1/metar.20220909.21Z.txt
# METAR_train_part_1/metar.20220915.02Z.txt
# METAR_train_part_1/metar.20221016.08Z.txt
# METAR_train_part_1/metar.20221008.16Z.txt
# METAR_train_part_1/metar.20221018.16Z.txt
# METAR_train_part_1/metar.20221006.08Z.txt
# METAR_train_part_1/metar.20220905.02Z.txt
# METAR_train_part_1/metar.20220919.21Z.txt
# METAR_train_part_1/metar.20221025.07Z.txt
# METAR_train_part_1/metar.20220906.04Z.txt
# METAR_train_part_1/metar.20220916.04Z.txt
# METAR_train_part_1/metar.20221026.17Z.txt
# METAR_train_part_1/metar.20220905.14Z.txt
# METAR_train_part_1/metar.20221004.23Z.txt
# METAR_train_part_1/metar.20221018.00Z.txt
# METAR_train_part_1/metar.20221008.00Z.txt
# METAR_train_part_1/metar.20221014.23Z.txt
# METAR_train_part_1/metar.20220915.14Z.txt
# METAR_train_part_1/metar.20220922.19Z.txt
# METAR_train_part_1/metar.20221021.13Z.txt
# METAR_train_part_1/metar.20220902.10Z.txt
# METAR_train_part_1/metar.20220912.10Z.txt
# METAR_train_part_1/metar.20221022.03Z.txt
# METAR_train_part_1/metar.20220921.09Z.txt
# METAR_train_part_1/metar.20220901.00Z.txt
# METAR_train_part_1/metar.20220911.00Z.txt
# METAR_train_part_1/metar.20220919.17Z.txt
# METAR_train_part_1/metar.20220907.09Z.txt
# METAR_train_part_1/metar.20221004.03Z.txt
# METAR_train_part_1/metar.20221018.20Z.txt
# METAR_train_part_1/metar.20221008.20Z.txt
# METAR_train_part_1/metar.20221014.03Z.txt
# METAR_train_part_1/metar.20220917.09Z.txt
# METAR_train_part_1/metar.20220909.17Z.txt
# METAR_train_part_1/metar.20221007.13Z.txt
# METAR_train_part_1/metar.20220904.19Z.txt
# METAR_train_part_1/metar.20220914.19Z.txt
# METAR_train_part_1/metar.20221017.13Z.txt
# METAR_train_part_1/metar.20220924.10Z.txt
# METAR_train_part_1/metar.20220901.20Z.txt
# METAR_train_part_1/metar.20221010.17Z.txt
# METAR_train_part_1/metar.20220911.20Z.txt
# METAR_train_part_1/metar.20221022.23Z.txt
# METAR_train_part_1/metar.20220923.14Z.txt
# METAR_train_part_1/metar.20221003.07Z.txt
# METAR_train_part_1/metar.20221013.07Z.txt
# METAR_train_part_1/metar.20220920.04Z.txt
# METAR_train_part_1/metar.20221010.01Z.txt
# METAR_train_part_1/metar.20220923.02Z.txt
# METAR_train_part_1/metar.20221020.08Z.txt
# METAR_train_part_1/metar.20221013.11Z.txt
# METAR_train_part_1/metar.20221003.11Z.txt
# METAR_train_part_1/metar.20221023.18Z.txt
# METAR_train_part_1/metar.20220920.12Z.txt
# METAR_train_part_1/metar.20220909.01Z.txt
# METAR_train_part_1/metar.20220915.22Z.txt
# METAR_train_part_1/metar.20221014.15Z.txt
# METAR_train_part_1/metar.20221004.15Z.txt
# METAR_train_part_1/metar.20220905.22Z.txt
# METAR_train_part_1/metar.20220919.01Z.txt
# METAR_train_part_1/metar.20221026.21Z.txt
# METAR_train_part_1/metar.20221017.05Z.txt
# METAR_train_part_1/metar.20221007.05Z.txt
# METAR_train_part_1/metar.20220924.06Z.txt
# METAR_train_part_1/metar.20221022.19Z.txt
# METAR_train_part_1/metar.20220921.13Z.txt
# METAR_train_part_1/metar.20221012.10Z.txt
# METAR_train_part_1/metar.20220922.03Z.txt
# METAR_train_part_1/metar.20221021.09Z.txt
# METAR_train_part_1/metar.20221011.00Z.txt
# METAR_train_part_1/metar.20221006.04Z.txt
# METAR_train_part_1/metar.20221016.04Z.txt
# METAR_train_part_1/metar.20221005.14Z.txt
# METAR_train_part_1/metar.20220918.00Z.txt
# METAR_train_part_1/metar.20220904.23Z.txt
# METAR_train_part_1/metar.20220914.23Z.txt
# METAR_train_part_1/metar.20220908.00Z.txt
# METAR_train_part_1/metar.20221015.14Z.txt
# METAR_train_part_1/metar.20220915.18Z.txt
# METAR_train_part_1/metar.20221016.12Z.txt
# METAR_train_part_1/metar.20221006.12Z.txt
# METAR_train_part_1/metar.20220905.18Z.txt
# METAR_train_part_1/metar.20221015.02Z.txt
# METAR_train_part_1/metar.20221009.21Z.txt
# METAR_train_part_1/metar.20220908.16Z.txt
# METAR_train_part_1/metar.20220916.08Z.txt
# METAR_train_part_1/metar.20220906.08Z.txt
# METAR_train_part_1/metar.20220918.16Z.txt
# METAR_train_part_1/metar.20221019.21Z.txt
# METAR_train_part_1/metar.20221005.02Z.txt
# METAR_train_part_1/metar.20220921.05Z.txt
# METAR_train_part_1/metar.20221012.06Z.txt
# METAR_train_part_1/metar.20221023.22Z.txt
# METAR_train_part_1/metar.20220922.15Z.txt
# METAR_train_part_1/metar.20221011.16Z.txt
# METAR_train_part_1/metar.20220910.21Z.txt
# METAR_train_part_1/metar.20221022.04Z.txt
# METAR_train_part_1/metar.20220911.07Z.txt
# METAR_train_part_1/metar.20220901.07Z.txt
# METAR_train_part_1/metar.20221021.14Z.txt
# METAR_train_part_1/metar.20220920.23Z.txt
# METAR_train_part_1/metar.20221013.20Z.txt
# METAR_train_part_1/metar.20220912.17Z.txt
# METAR_train_part_1/metar.20220902.17Z.txt
# METAR_train_part_1/metar.20221003.20Z.txt
# METAR_train_part_1/metar.20221026.10Z.txt
# METAR_train_part_1/metar.20220915.13Z.txt
# METAR_train_part_1/metar.20221008.07Z.txt
# METAR_train_part_1/metar.20221016.19Z.txt
# METAR_train_part_1/metar.20221006.19Z.txt
# METAR_train_part_1/metar.20221018.07Z.txt
# METAR_train_part_1/metar.20220905.13Z.txt
# METAR_train_part_1/metar.20221025.00Z.txt
# METAR_train_part_1/metar.20221015.09Z.txt
# METAR_train_part_1/metar.20220916.03Z.txt
# METAR_train_part_1/metar.20220906.03Z.txt
# METAR_train_part_1/metar.20221005.09Z.txt
# METAR_train_part_1/metar.20221026.06Z.txt
# METAR_train_part_1/metar.20220905.05Z.txt
# METAR_train_part_1/metar.20221018.11Z.txt
# METAR_train_part_1/metar.20221008.11Z.txt
# METAR_train_part_1/metar.20220915.05Z.txt
# METAR_train_part_1/metar.20220924.21Z.txt
# METAR_train_part_1/metar.20221025.16Z.txt
# METAR_train_part_1/metar.20221007.22Z.txt
# METAR_train_part_1/metar.20220906.15Z.txt
# METAR_train_part_1/metar.20220916.15Z.txt
# METAR_train_part_1/metar.20221017.22Z.txt
# METAR_train_part_1/metar.20221022.12Z.txt
# METAR_train_part_1/metar.20220921.18Z.txt
# METAR_train_part_1/metar.20220901.11Z.txt
# METAR_train_part_1/metar.20220911.11Z.txt
# METAR_train_part_1/metar.20220922.08Z.txt
# METAR_train_part_1/metar.20221021.02Z.txt
# METAR_train_part_1/metar.20220902.01Z.txt
# METAR_train_part_1/metar.20220912.01Z.txt
# METAR_train_part_1/metar.20220917.14Z.txt
# METAR_train_part_1/metar.20221016.23Z.txt
# METAR_train_part_1/metar.20221006.23Z.txt
# METAR_train_part_1/metar.20220907.14Z.txt
# METAR_train_part_1/metar.20221024.17Z.txt
# METAR_train_part_1/metar.20221009.10Z.txt
# METAR_train_part_1/metar.20220914.04Z.txt
# METAR_train_part_1/metar.20220904.04Z.txt
# METAR_train_part_1/metar.20221019.10Z.txt
# METAR_train_part_1/metar.20220913.00Z.txt
# METAR_train_part_1/metar.20220903.00Z.txt
# METAR_train_part_1/metar.20220923.09Z.txt
# METAR_train_part_1/metar.20221020.03Z.txt
# METAR_train_part_1/metar.20220910.10Z.txt
# METAR_train_part_1/metar.20221023.13Z.txt
# METAR_train_part_1/metar.20220920.19Z.txt
# METAR_train_part_1/metar.20220903.16Z.txt
# METAR_train_part_1/metar.20221012.21Z.txt
# METAR_train_part_1/metar.20220913.16Z.txt
# METAR_train_part_1/metar.20221020.15Z.txt
# METAR_train_part_1/metar.20220921.22Z.txt
# METAR_train_part_1/metar.20220910.06Z.txt
# METAR_train_part_1/metar.20221023.05Z.txt
# METAR_train_part_1/metar.20220907.02Z.txt
# METAR_train_part_1/metar.20221004.08Z.txt
# METAR_train_part_1/metar.20221014.08Z.txt
# METAR_train_part_1/metar.20220917.02Z.txt
# METAR_train_part_1/metar.20221024.01Z.txt
# METAR_train_part_1/metar.20221019.06Z.txt
# METAR_train_part_1/metar.20221007.18Z.txt
# METAR_train_part_1/metar.20220904.12Z.txt
# METAR_train_part_1/metar.20220914.12Z.txt
# METAR_train_part_1/metar.20221017.18Z.txt
# METAR_train_part_1/metar.20221009.06Z.txt
# METAR_train_part_1/metar.20220922.12Z.txt
# METAR_train_part_1/metar.20221021.18Z.txt
# METAR_train_part_1/metar.20221011.11Z.txt
# METAR_train_part_1/metar.20221022.08Z.txt
# METAR_train_part_1/metar.20220921.02Z.txt
# METAR_train_part_1/metar.20221012.01Z.txt
# METAR_train_part_1/metar.20221005.05Z.txt
# METAR_train_part_1/metar.20220918.11Z.txt
# METAR_train_part_1/metar.20220908.11Z.txt
# METAR_train_part_1/metar.20221015.05Z.txt
# METAR_train_part_1/metar.20221024.21Z.txt
# METAR_train_part_1/metar.20220907.22Z.txt
# METAR_train_part_1/metar.20221006.15Z.txt
# METAR_train_part_1/metar.20221016.15Z.txt
# METAR_train_part_1/metar.20220917.22Z.txt
# METAR_train_part_1/metar.20221015.13Z.txt
# METAR_train_part_1/metar.20220916.19Z.txt
# METAR_train_part_1/metar.20220908.07Z.txt
# METAR_train_part_1/metar.20220918.07Z.txt
# METAR_train_part_1/metar.20220906.19Z.txt
# METAR_train_part_1/metar.20221005.13Z.txt
# METAR_train_part_1/metar.20220915.09Z.txt
# METAR_train_part_1/metar.20221016.03Z.txt
# METAR_train_part_1/metar.20221006.03Z.txt
# METAR_train_part_1/metar.20220905.09Z.txt
# METAR_train_part_1/metar.20220922.04Z.txt
# METAR_train_part_1/metar.20221011.07Z.txt
# METAR_train_part_1/metar.20220921.14Z.txt
# METAR_train_part_1/metar.20221020.23Z.txt
# METAR_train_part_1/metar.20220913.20Z.txt
# METAR_train_part_1/metar.20221012.17Z.txt
# METAR_train_part_1/metar.20220903.20Z.txt
# METAR_train_part_1/metar.20221007.02Z.txt
# METAR_train_part_1/metar.20220904.08Z.txt
# METAR_train_part_1/metar.20220914.08Z.txt
# METAR_train_part_1/metar.20221017.02Z.txt
# METAR_train_part_1/metar.20220924.01Z.txt
# METAR_train_part_1/metar.20220907.18Z.txt
# METAR_train_part_1/metar.20220919.06Z.txt
# METAR_train_part_1/metar.20221004.12Z.txt
# METAR_train_part_1/metar.20221014.12Z.txt
# METAR_train_part_1/metar.20220909.06Z.txt
# METAR_train_part_1/metar.20220917.18Z.txt
# METAR_train_part_1/metar.20221003.16Z.txt
# METAR_train_part_1/metar.20220902.21Z.txt
# METAR_train_part_1/metar.20220912.21Z.txt
# METAR_train_part_1/metar.20221013.16Z.txt
# METAR_train_part_1/metar.20220920.15Z.txt
# METAR_train_part_1/metar.20221021.22Z.txt
# METAR_train_part_1/metar.20221010.06Z.txt
# METAR_train_part_1/metar.20220923.05Z.txt
# METAR_train_part_1/metar.20221013.00Z.txt
# METAR_train_part_1/metar.20221003.00Z.txt
# METAR_train_part_1/metar.20221023.09Z.txt
# METAR_train_part_1/metar.20220920.03Z.txt
# METAR_train_part_1/metar.20221010.10Z.txt
# METAR_train_part_1/metar.20220923.13Z.txt
# METAR_train_part_1/metar.20221020.19Z.txt
# METAR_train_part_1/metar.20221017.14Z.txt
# METAR_train_part_1/metar.20220916.23Z.txt
# METAR_train_part_1/metar.20220906.23Z.txt
# METAR_train_part_1/metar.20221007.14Z.txt
# METAR_train_part_1/metar.20221025.20Z.txt
# METAR_train_part_1/metar.20220924.17Z.txt
# METAR_train_part_1/metar.20220909.10Z.txt
# METAR_train_part_1/metar.20221014.04Z.txt
# METAR_train_part_1/metar.20221004.04Z.txt
# METAR_train_part_1/metar.20220919.10Z.txt
# METAR_train_part_1/metar.20220909.11Z.txt
# METAR_train_part_1/metar.20221014.05Z.txt
# METAR_train_part_1/metar.20221004.05Z.txt
# METAR_train_part_1/metar.20220919.11Z.txt
# METAR_train_part_1/metar.20221017.15Z.txt
# METAR_train_part_1/metar.20220916.22Z.txt
# METAR_train_part_1/metar.20220906.22Z.txt
# METAR_train_part_1/metar.20221007.15Z.txt
# METAR_train_part_1/metar.20221025.21Z.txt
# METAR_train_part_1/metar.20220924.16Z.txt
# METAR_train_part_1/metar.20221010.11Z.txt
# METAR_train_part_1/metar.20220923.12Z.txt
# METAR_train_part_1/metar.20221020.18Z.txt
# METAR_train_part_1/metar.20221013.01Z.txt
# METAR_train_part_1/metar.20221003.01Z.txt
# METAR_train_part_1/metar.20221023.08Z.txt
# METAR_train_part_1/metar.20220920.02Z.txt
# METAR_train_part_1/metar.20221010.07Z.txt
# METAR_train_part_1/metar.20220923.04Z.txt
# METAR_train_part_1/metar.20221003.17Z.txt
# METAR_train_part_1/metar.20220902.20Z.txt
# METAR_train_part_1/metar.20220912.20Z.txt
# METAR_train_part_1/metar.20221013.17Z.txt
# METAR_train_part_1/metar.20220920.14Z.txt
# METAR_train_part_1/metar.20221021.23Z.txt
# METAR_train_part_1/metar.20220907.19Z.txt
# METAR_train_part_1/metar.20220919.07Z.txt
# METAR_train_part_1/metar.20221004.13Z.txt
# METAR_train_part_1/metar.20221014.13Z.txt
# METAR_train_part_1/metar.20220909.07Z.txt
# METAR_train_part_1/metar.20220917.19Z.txt
# METAR_train_part_1/metar.20221007.03Z.txt
# METAR_train_part_1/metar.20220904.09Z.txt
# METAR_train_part_1/metar.20220914.09Z.txt
# METAR_train_part_1/metar.20221017.03Z.txt
# METAR_train_part_1/metar.20220924.00Z.txt
# METAR_train_part_1/metar.20220921.15Z.txt
# METAR_train_part_1/metar.20221020.22Z.txt
# METAR_train_part_1/metar.20220913.21Z.txt
# METAR_train_part_1/metar.20221012.16Z.txt
# METAR_train_part_1/metar.20220903.21Z.txt
# METAR_train_part_1/metar.20220922.05Z.txt
# METAR_train_part_1/metar.20221011.06Z.txt
# METAR_train_part_1/metar.20220915.08Z.txt
# METAR_train_part_1/metar.20221016.02Z.txt
# METAR_train_part_1/metar.20221006.02Z.txt
# METAR_train_part_1/metar.20220905.08Z.txt
# METAR_train_part_1/metar.20221015.12Z.txt
# METAR_train_part_1/metar.20220916.18Z.txt
# METAR_train_part_1/metar.20220908.06Z.txt
# METAR_train_part_1/metar.20220918.06Z.txt
# METAR_train_part_1/metar.20220906.18Z.txt
# METAR_train_part_1/metar.20221005.12Z.txt
# METAR_train_part_1/metar.20221024.20Z.txt
# METAR_train_part_1/metar.20220907.23Z.txt
# METAR_train_part_1/metar.20221006.14Z.txt
# METAR_train_part_1/metar.20221016.14Z.txt
# METAR_train_part_1/metar.20220917.23Z.txt
# METAR_train_part_1/metar.20221005.04Z.txt
# METAR_train_part_1/metar.20220918.10Z.txt
# METAR_train_part_1/metar.20220908.10Z.txt
# METAR_train_part_1/metar.20221015.04Z.txt
# METAR_train_part_1/metar.20221022.09Z.txt
# METAR_train_part_1/metar.20220921.03Z.txt
# METAR_train_part_1/metar.20221012.00Z.txt
# METAR_train_part_1/metar.20220922.13Z.txt
# METAR_train_part_1/metar.20221021.19Z.txt
# METAR_train_part_1/metar.20221011.10Z.txt
# METAR_train_part_1/metar.20221019.07Z.txt
# METAR_train_part_1/metar.20221007.19Z.txt
# METAR_train_part_1/metar.20220904.13Z.txt
# METAR_train_part_1/metar.20220914.13Z.txt
# METAR_train_part_1/metar.20221017.19Z.txt
# METAR_train_part_1/metar.20221009.07Z.txt
# METAR_train_part_1/metar.20220907.03Z.txt
# METAR_train_part_1/metar.20221004.09Z.txt
# METAR_train_part_1/metar.20221014.09Z.txt
# METAR_train_part_1/metar.20220917.03Z.txt
# METAR_train_part_1/metar.20221024.00Z.txt
# METAR_train_part_1/metar.20220910.07Z.txt
# METAR_train_part_1/metar.20221023.04Z.txt
# METAR_train_part_1/metar.20220903.17Z.txt
# METAR_train_part_1/metar.20221012.20Z.txt
# METAR_train_part_1/metar.20220913.17Z.txt
# METAR_train_part_1/metar.20221020.14Z.txt
# METAR_train_part_1/metar.20220921.23Z.txt
# METAR_train_part_1/metar.20220910.11Z.txt
# METAR_train_part_1/metar.20221023.12Z.txt
# METAR_train_part_1/metar.20220920.18Z.txt
# METAR_train_part_1/metar.20220913.01Z.txt
# METAR_train_part_1/metar.20220903.01Z.txt
# METAR_train_part_1/metar.20220923.08Z.txt
# METAR_train_part_1/metar.20221020.02Z.txt
# METAR_train_part_1/metar.20221009.11Z.txt
# METAR_train_part_1/metar.20220914.05Z.txt
# METAR_train_part_1/metar.20220904.05Z.txt
# METAR_train_part_1/metar.20221019.11Z.txt
# METAR_train_part_1/metar.20220917.15Z.txt
# METAR_train_part_1/metar.20221016.22Z.txt
# METAR_train_part_1/metar.20221006.22Z.txt
# METAR_train_part_1/metar.20220907.15Z.txt
# METAR_train_part_1/metar.20221024.16Z.txt
# METAR_train_part_1/metar.20220922.09Z.txt
# METAR_train_part_1/metar.20221021.03Z.txt
# METAR_train_part_1/metar.20220902.00Z.txt
# METAR_train_part_1/metar.20220912.00Z.txt
# METAR_train_part_1/metar.20221022.13Z.txt
# METAR_train_part_1/metar.20220921.19Z.txt
# METAR_train_part_1/metar.20220901.10Z.txt
# METAR_train_part_1/metar.20220911.10Z.txt
# METAR_train_part_1/metar.20220924.20Z.txt
# METAR_train_part_1/metar.20221025.17Z.txt
# METAR_train_part_1/metar.20221007.23Z.txt
# METAR_train_part_1/metar.20220906.14Z.txt
# METAR_train_part_1/metar.20220916.14Z.txt
# METAR_train_part_1/metar.20221017.23Z.txt
# METAR_train_part_1/metar.20221026.07Z.txt
# METAR_train_part_1/metar.20220905.04Z.txt
# METAR_train_part_1/metar.20221018.10Z.txt
# METAR_train_part_1/metar.20221008.10Z.txt
# METAR_train_part_1/metar.20220915.04Z.txt
# METAR_train_part_1/metar.20221025.01Z.txt
# METAR_train_part_1/metar.20221015.08Z.txt
# METAR_train_part_1/metar.20220916.02Z.txt
# METAR_train_part_1/metar.20220906.02Z.txt
# METAR_train_part_1/metar.20221005.08Z.txt
# METAR_train_part_1/metar.20221026.11Z.txt
# METAR_train_part_1/metar.20220915.12Z.txt
# METAR_train_part_1/metar.20221008.06Z.txt
# METAR_train_part_1/metar.20221016.18Z.txt
# METAR_train_part_1/metar.20221006.18Z.txt
# METAR_train_part_1/metar.20221018.06Z.txt
# METAR_train_part_1/metar.20220905.12Z.txt
# METAR_train_part_1/metar.20221021.15Z.txt
# METAR_train_part_1/metar.20220920.22Z.txt
# METAR_train_part_1/metar.20221013.21Z.txt
# METAR_train_part_1/metar.20220912.16Z.txt
# METAR_train_part_1/metar.20220902.16Z.txt
# METAR_train_part_1/metar.20221003.21Z.txt
# METAR_train_part_1/metar.20221022.05Z.txt
# METAR_train_part_1/metar.20220911.06Z.txt
# METAR_train_part_1/metar.20220901.06Z.txt
# METAR_train_part_1/metar.20220924.19Z.txt
# METAR_train_part_1/metar.20220914.10Z.txt
# METAR_train_part_1/metar.20221009.04Z.txt
# METAR_train_part_1/metar.20221019.04Z.txt
# METAR_train_part_1/metar.20220904.10Z.txt
# METAR_train_part_1/metar.20221024.03Z.txt
# METAR_train_part_1/metar.20220917.00Z.txt
# METAR_train_part_1/metar.20220907.00Z.txt
# METAR_train_part_1/metar.20221023.07Z.txt
# METAR_train_part_1/metar.20220910.04Z.txt
# METAR_train_part_1/metar.20221020.17Z.txt
# METAR_train_part_1/metar.20220921.20Z.txt
# METAR_train_part_1/metar.20221012.23Z.txt
# METAR_train_part_1/metar.20220913.14Z.txt
# METAR_train_part_1/metar.20220903.14Z.txt
# METAR_train_part_1/metar.20221023.11Z.txt
# METAR_train_part_1/metar.20221003.18Z.txt
# METAR_train_part_1/metar.20221013.18Z.txt
# METAR_train_part_1/metar.20220910.12Z.txt
# METAR_train_part_1/metar.20221020.01Z.txt
# METAR_train_part_1/metar.20220903.02Z.txt
# METAR_train_part_1/metar.20220913.02Z.txt
# METAR_train_part_1/metar.20221010.08Z.txt
# METAR_train_part_1/metar.20220904.06Z.txt
# METAR_train_part_1/metar.20221019.12Z.txt
# METAR_train_part_1/metar.20221009.12Z.txt
# METAR_train_part_1/metar.20220914.06Z.txt
# METAR_train_part_1/metar.20221024.15Z.txt
# METAR_train_part_1/metar.20221006.21Z.txt
# METAR_train_part_1/metar.20220919.08Z.txt
# METAR_train_part_1/metar.20220907.16Z.txt
# METAR_train_part_1/metar.20220917.16Z.txt
# METAR_train_part_1/metar.20220909.08Z.txt
# METAR_train_part_1/metar.20221016.21Z.txt
# METAR_train_part_1/metar.20220912.03Z.txt
# METAR_train_part_1/metar.20221011.09Z.txt
# METAR_train_part_1/metar.20220902.03Z.txt
# METAR_train_part_1/metar.20221021.00Z.txt
# METAR_train_part_1/metar.20221012.19Z.txt
# METAR_train_part_1/metar.20220911.13Z.txt
# METAR_train_part_1/metar.20220901.13Z.txt
# METAR_train_part_1/metar.20221022.10Z.txt
# METAR_train_part_1/metar.20220908.09Z.txt
# METAR_train_part_1/metar.20220916.17Z.txt
# METAR_train_part_1/metar.20221017.20Z.txt
# METAR_train_part_1/metar.20221007.20Z.txt
# METAR_train_part_1/metar.20220906.17Z.txt
# METAR_train_part_1/metar.20220918.09Z.txt
# METAR_train_part_1/metar.20220924.23Z.txt
# METAR_train_part_1/metar.20221025.14Z.txt
# METAR_train_part_1/metar.20221008.13Z.txt
# METAR_train_part_1/metar.20220915.07Z.txt
# METAR_train_part_1/metar.20220905.07Z.txt
# METAR_train_part_1/metar.20221018.13Z.txt
# METAR_train_part_1/metar.20221026.04Z.txt
# METAR_train_part_1/metar.20220906.01Z.txt
# METAR_train_part_1/metar.20220916.01Z.txt
# METAR_train_part_1/metar.20221025.02Z.txt
# METAR_train_part_1/metar.20221018.05Z.txt
# METAR_train_part_1/metar.20220905.11Z.txt
# METAR_train_part_1/metar.20220915.11Z.txt
# METAR_train_part_1/metar.20221008.05Z.txt
# METAR_train_part_1/metar.20221026.12Z.txt
# METAR_train_part_1/metar.20220902.15Z.txt
# METAR_train_part_1/metar.20221003.22Z.txt
# METAR_train_part_1/metar.20221013.22Z.txt
# METAR_train_part_1/metar.20220912.15Z.txt
# METAR_train_part_1/metar.20221021.16Z.txt
# METAR_train_part_1/metar.20220920.21Z.txt
# METAR_train_part_1/metar.20220901.05Z.txt
# METAR_train_part_1/metar.20220911.05Z.txt
# METAR_train_part_1/metar.20221022.06Z.txt
# METAR_train_part_1/metar.20221004.06Z.txt
# METAR_train_part_1/metar.20220919.12Z.txt
# METAR_train_part_1/metar.20220909.12Z.txt
# METAR_train_part_1/metar.20221014.06Z.txt
# METAR_train_part_1/metar.20221025.22Z.txt
# METAR_train_part_1/metar.20220924.15Z.txt
# METAR_train_part_1/metar.20220906.21Z.txt
# METAR_train_part_1/metar.20221007.16Z.txt
# METAR_train_part_1/metar.20221019.08Z.txt
# METAR_train_part_1/metar.20221009.08Z.txt
# METAR_train_part_1/metar.20221017.16Z.txt
# METAR_train_part_1/metar.20220916.21Z.txt
# METAR_train_part_1/metar.20220923.11Z.txt
# METAR_train_part_1/metar.20220903.18Z.txt
# METAR_train_part_1/metar.20220913.18Z.txt
# METAR_train_part_1/metar.20221010.12Z.txt
# METAR_train_part_1/metar.20220920.01Z.txt
# METAR_train_part_1/metar.20221003.02Z.txt
# METAR_train_part_1/metar.20221013.02Z.txt
# METAR_train_part_1/metar.20220910.08Z.txt
# METAR_train_part_1/metar.20220923.07Z.txt
# METAR_train_part_1/metar.20221010.04Z.txt
# METAR_train_part_1/metar.20220920.17Z.txt
# METAR_train_part_1/metar.20221021.20Z.txt
# METAR_train_part_1/metar.20220912.23Z.txt
# METAR_train_part_1/metar.20221013.14Z.txt
# METAR_train_part_1/metar.20221003.14Z.txt
# METAR_train_part_1/metar.20220902.23Z.txt
# METAR_train_part_1/metar.20221024.19Z.txt
# METAR_train_part_1/metar.20221014.10Z.txt
# METAR_train_part_1/metar.20220909.04Z.txt
# METAR_train_part_1/metar.20220919.04Z.txt
# METAR_train_part_1/metar.20221004.10Z.txt
# METAR_train_part_1/metar.20220924.03Z.txt
# METAR_train_part_1/metar.20221017.00Z.txt
# METAR_train_part_1/metar.20221007.00Z.txt
# METAR_train_part_1/metar.20220903.22Z.txt
# METAR_train_part_1/metar.20220913.22Z.txt
# METAR_train_part_1/metar.20221012.15Z.txt
# METAR_train_part_1/metar.20220921.16Z.txt
# METAR_train_part_1/metar.20221020.21Z.txt
# METAR_train_part_1/metar.20221011.05Z.txt
# METAR_train_part_1/metar.20220922.06Z.txt
# METAR_train_part_1/metar.20221006.01Z.txt
# METAR_train_part_1/metar.20221016.01Z.txt
# METAR_train_part_1/metar.20221026.08Z.txt
# METAR_train_part_1/metar.20220918.05Z.txt
# METAR_train_part_1/metar.20221005.11Z.txt
# METAR_train_part_1/metar.20221015.11Z.txt
# METAR_train_part_1/metar.20220908.05Z.txt
# METAR_train_part_1/metar.20221025.18Z.txt
# METAR_train_part_1/metar.20221016.17Z.txt
# METAR_train_part_1/metar.20221008.09Z.txt
# METAR_train_part_1/metar.20220917.20Z.txt
# METAR_train_part_1/metar.20220907.20Z.txt
# METAR_train_part_1/metar.20221018.09Z.txt
# METAR_train_part_1/metar.20221006.17Z.txt
# METAR_train_part_1/metar.20221024.23Z.txt
# METAR_train_part_1/metar.20220908.13Z.txt
# METAR_train_part_1/metar.20221015.07Z.txt
# METAR_train_part_1/metar.20221005.07Z.txt
# METAR_train_part_1/metar.20220918.13Z.txt
# METAR_train_part_1/metar.20221012.03Z.txt
# METAR_train_part_1/metar.20220911.09Z.txt
# METAR_train_part_1/metar.20220901.09Z.txt
# METAR_train_part_1/metar.20220921.00Z.txt
# METAR_train_part_1/metar.20220912.19Z.txt
# METAR_train_part_1/metar.20221011.13Z.txt
# METAR_train_part_1/metar.20220902.19Z.txt
# METAR_train_part_1/metar.20220922.10Z.txt
# METAR_train_part_1/metar.20220912.18Z.txt
# METAR_train_part_1/metar.20221011.12Z.txt
# METAR_train_part_1/metar.20220902.18Z.txt
# METAR_train_part_1/metar.20220922.11Z.txt
# METAR_train_part_1/metar.20221012.02Z.txt
# METAR_train_part_1/metar.20220911.08Z.txt
# METAR_train_part_1/metar.20220901.08Z.txt
# METAR_train_part_1/metar.20220921.01Z.txt
# METAR_train_part_1/metar.20220908.12Z.txt
# METAR_train_part_1/metar.20221015.06Z.txt
# METAR_train_part_1/metar.20221005.06Z.txt
# METAR_train_part_1/metar.20220918.12Z.txt
# METAR_train_part_1/metar.20221016.16Z.txt
# METAR_train_part_1/metar.20221008.08Z.txt
# METAR_train_part_1/metar.20220917.21Z.txt
# METAR_train_part_1/metar.20220907.21Z.txt
# METAR_train_part_1/metar.20221018.08Z.txt
# METAR_train_part_1/metar.20221006.16Z.txt
# METAR_train_part_1/metar.20221024.22Z.txt
# METAR_train_part_1/metar.20220918.04Z.txt
# METAR_train_part_1/metar.20221005.10Z.txt
# METAR_train_part_1/metar.20221015.10Z.txt
# METAR_train_part_1/metar.20220908.04Z.txt
# METAR_train_part_1/metar.20221025.19Z.txt
# METAR_train_part_1/metar.20221006.00Z.txt
# METAR_train_part_1/metar.20221016.00Z.txt
# METAR_train_part_1/metar.20221026.09Z.txt
# METAR_train_part_1/metar.20221011.04Z.txt
# METAR_train_part_1/metar.20220922.07Z.txt
# METAR_train_part_1/metar.20220903.23Z.txt
# METAR_train_part_1/metar.20220913.23Z.txt
# METAR_train_part_1/metar.20221012.14Z.txt
# METAR_train_part_1/metar.20220921.17Z.txt
# METAR_train_part_1/metar.20221020.20Z.txt
# METAR_train_part_1/metar.20220924.02Z.txt
# METAR_train_part_1/metar.20221017.01Z.txt
# METAR_train_part_1/metar.20221007.01Z.txt
# METAR_train_part_1/metar.20221024.18Z.txt
# METAR_train_part_1/metar.20221014.11Z.txt
# METAR_train_part_1/metar.20220909.05Z.txt
# METAR_train_part_1/metar.20220919.05Z.txt
# METAR_train_part_1/metar.20221004.11Z.txt
# METAR_train_part_1/metar.20220920.16Z.txt
# METAR_train_part_1/metar.20221021.21Z.txt
# METAR_train_part_1/metar.20220912.22Z.txt
# METAR_train_part_1/metar.20221013.15Z.txt
# METAR_train_part_1/metar.20221003.15Z.txt
# METAR_train_part_1/metar.20220902.22Z.txt
# METAR_train_part_1/metar.20220923.06Z.txt
# METAR_train_part_1/metar.20221010.05Z.txt
# METAR_train_part_1/metar.20220920.00Z.txt
# METAR_train_part_1/metar.20221003.03Z.txt
# METAR_train_part_1/metar.20221013.03Z.txt
# METAR_train_part_1/metar.20220910.09Z.txt
# METAR_train_part_1/metar.20220923.10Z.txt
# METAR_train_part_1/metar.20220903.19Z.txt
# METAR_train_part_1/metar.20220913.19Z.txt
# METAR_train_part_1/metar.20221010.13Z.txt
# METAR_train_part_1/metar.20221025.23Z.txt
# METAR_train_part_1/metar.20220924.14Z.txt
# METAR_train_part_1/metar.20220906.20Z.txt
# METAR_train_part_1/metar.20221007.17Z.txt
# METAR_train_part_1/metar.20221019.09Z.txt
# METAR_train_part_1/metar.20221009.09Z.txt
# METAR_train_part_1/metar.20221017.17Z.txt
# METAR_train_part_1/metar.20220916.20Z.txt
# METAR_train_part_1/metar.20221004.07Z.txt
# METAR_train_part_1/metar.20220919.13Z.txt
# METAR_train_part_1/metar.20220909.13Z.txt
# METAR_train_part_1/metar.20221014.07Z.txt
# METAR_train_part_1/metar.20220901.04Z.txt
# METAR_train_part_1/metar.20220911.04Z.txt
# METAR_train_part_1/metar.20221022.07Z.txt
# METAR_train_part_1/metar.20220902.14Z.txt
# METAR_train_part_1/metar.20221003.23Z.txt
# METAR_train_part_1/metar.20221013.23Z.txt
# METAR_train_part_1/metar.20220912.14Z.txt
# METAR_train_part_1/metar.20221021.17Z.txt
# METAR_train_part_1/metar.20220920.20Z.txt
# METAR_train_part_1/metar.20221018.04Z.txt
# METAR_train_part_1/metar.20220905.10Z.txt
# METAR_train_part_1/metar.20220915.10Z.txt
# METAR_train_part_1/metar.20221008.04Z.txt
# METAR_train_part_1/metar.20221026.13Z.txt
# METAR_train_part_1/metar.20220906.00Z.txt
# METAR_train_part_1/metar.20220916.00Z.txt
# METAR_train_part_1/metar.20221025.03Z.txt
# METAR_train_part_1/metar.20221008.12Z.txt
# METAR_train_part_1/metar.20220915.06Z.txt
# METAR_train_part_1/metar.20220905.06Z.txt
# METAR_train_part_1/metar.20221018.12Z.txt
# METAR_train_part_1/metar.20221026.05Z.txt
# METAR_train_part_1/metar.20220908.08Z.txt
# METAR_train_part_1/metar.20220916.16Z.txt
# METAR_train_part_1/metar.20221017.21Z.txt
# METAR_train_part_1/metar.20221007.21Z.txt
# METAR_train_part_1/metar.20220906.16Z.txt
# METAR_train_part_1/metar.20220918.08Z.txt
# METAR_train_part_1/metar.20220924.22Z.txt
# METAR_train_part_1/metar.20221025.15Z.txt
# METAR_train_part_1/metar.20221012.18Z.txt
# METAR_train_part_1/metar.20220911.12Z.txt
# METAR_train_part_1/metar.20220901.12Z.txt
# METAR_train_part_1/metar.20221022.11Z.txt
# METAR_train_part_1/metar.20220912.02Z.txt
# METAR_train_part_1/metar.20221011.08Z.txt
# METAR_train_part_1/metar.20220902.02Z.txt
# METAR_train_part_1/metar.20221021.01Z.txt
# METAR_train_part_1/metar.20221024.14Z.txt
# METAR_train_part_1/metar.20221006.20Z.txt
# METAR_train_part_1/metar.20220919.09Z.txt
# METAR_train_part_1/metar.20220907.17Z.txt
# METAR_train_part_1/metar.20220917.17Z.txt
# METAR_train_part_1/metar.20220909.09Z.txt
# METAR_train_part_1/metar.20221016.20Z.txt
# METAR_train_part_1/metar.20220904.07Z.txt
# METAR_train_part_1/metar.20221019.13Z.txt
# METAR_train_part_1/metar.20221009.13Z.txt
# METAR_train_part_1/metar.20220914.07Z.txt
# METAR_train_part_1/metar.20221020.00Z.txt
# METAR_train_part_1/metar.20220903.03Z.txt
# METAR_train_part_1/metar.20220913.03Z.txt
# METAR_train_part_1/metar.20221010.09Z.txt
# METAR_train_part_1/metar.20221023.10Z.txt
# METAR_train_part_1/metar.20221003.19Z.txt
# METAR_train_part_1/metar.20221013.19Z.txt
# METAR_train_part_1/metar.20220910.13Z.txt
# METAR_train_part_1/metar.20221020.16Z.txt
# METAR_train_part_1/metar.20220921.21Z.txt
# METAR_train_part_1/metar.20221012.22Z.txt
# METAR_train_part_1/metar.20220913.15Z.txt
# METAR_train_part_1/metar.20220903.15Z.txt
# METAR_train_part_1/metar.20221023.06Z.txt
# METAR_train_part_1/metar.20220910.05Z.txt
# METAR_train_part_1/metar.20221024.02Z.txt
# METAR_train_part_1/metar.20220917.01Z.txt
# METAR_train_part_1/metar.20220907.01Z.txt
# METAR_train_part_1/metar.20220924.18Z.txt
# METAR_train_part_1/metar.20220914.11Z.txt
# METAR_train_part_1/metar.20221009.05Z.txt
# METAR_train_part_1/metar.20221019.05Z.txt
# METAR_train_part_1/metar.20220904.11Z.txt
# METAR_train_part_1/metar.20221024.09Z.txt
# METAR_train_part_1/metar.20221014.00Z.txt
# METAR_train_part_1/metar.20221008.23Z.txt
# METAR_train_part_1/metar.20220909.14Z.txt
# METAR_train_part_1/metar.20220919.14Z.txt
# METAR_train_part_1/metar.20221018.23Z.txt
# METAR_train_part_1/metar.20221004.00Z.txt
# METAR_train_part_1/metar.20220924.13Z.txt
# METAR_train_part_1/metar.20221017.10Z.txt
# METAR_train_part_1/metar.20221007.10Z.txt
# METAR_train_part_1/metar.20221022.20Z.txt
# METAR_train_part_1/metar.20220923.17Z.txt
# METAR_train_part_1/metar.20221010.14Z.txt
# METAR_train_part_1/metar.20220911.23Z.txt
# METAR_train_part_1/metar.20220901.23Z.txt
# METAR_train_part_1/metar.20220920.07Z.txt
# METAR_train_part_1/metar.20221013.04Z.txt
# METAR_train_part_1/metar.20221003.04Z.txt
# METAR_train_part_1/metar.20220923.01Z.txt
# METAR_train_part_1/metar.20220903.08Z.txt
# METAR_train_part_1/metar.20220913.08Z.txt
# METAR_train_part_1/metar.20221010.02Z.txt
# METAR_train_part_1/metar.20220920.11Z.txt
# METAR_train_part_1/metar.20221003.12Z.txt
# METAR_train_part_1/metar.20221013.12Z.txt
# METAR_train_part_1/metar.20220910.18Z.txt
# METAR_train_part_1/metar.20221026.22Z.txt
# METAR_train_part_1/metar.20221004.16Z.txt
# METAR_train_part_1/metar.20220919.02Z.txt
# METAR_train_part_1/metar.20220905.21Z.txt
# METAR_train_part_1/metar.20220915.21Z.txt
# METAR_train_part_1/metar.20220909.02Z.txt
# METAR_train_part_1/metar.20221014.16Z.txt
# METAR_train_part_1/metar.20220924.05Z.txt
# METAR_train_part_1/metar.20221019.18Z.txt
# METAR_train_part_1/metar.20221007.06Z.txt
# METAR_train_part_1/metar.20221017.06Z.txt
# METAR_train_part_1/metar.20221009.18Z.txt
# METAR_train_part_1/metar.20221012.13Z.txt
# METAR_train_part_1/metar.20220911.19Z.txt
# METAR_train_part_1/metar.20220901.19Z.txt
# METAR_train_part_1/metar.20220921.10Z.txt
# METAR_train_part_1/metar.20220912.09Z.txt
# METAR_train_part_1/metar.20221011.03Z.txt
# METAR_train_part_1/metar.20220902.09Z.txt
# METAR_train_part_1/metar.20220922.00Z.txt
# METAR_train_part_1/metar.20221008.19Z.txt
# METAR_train_part_1/metar.20221016.07Z.txt
# METAR_train_part_1/metar.20221006.07Z.txt
# METAR_train_part_1/metar.20221018.19Z.txt
# METAR_train_part_1/metar.20220908.03Z.txt
# METAR_train_part_1/metar.20220914.20Z.txt
# METAR_train_part_1/metar.20221015.17Z.txt
# METAR_train_part_1/metar.20221005.17Z.txt
# METAR_train_part_1/metar.20220904.20Z.txt
# METAR_train_part_1/metar.20220918.03Z.txt
# METAR_train_part_1/metar.20221006.11Z.txt
# METAR_train_part_1/metar.20221016.11Z.txt
# METAR_train_part_1/metar.20221026.18Z.txt
# METAR_train_part_1/metar.20220918.15Z.txt
# METAR_train_part_1/metar.20221005.01Z.txt
# METAR_train_part_1/metar.20221019.22Z.txt
# METAR_train_part_1/metar.20221009.22Z.txt
# METAR_train_part_1/metar.20221015.01Z.txt
# METAR_train_part_1/metar.20220908.15Z.txt
# METAR_train_part_1/metar.20221025.08Z.txt
# METAR_train_part_1/metar.20221012.05Z.txt
# METAR_train_part_1/metar.20220921.06Z.txt
# METAR_train_part_1/metar.20221011.15Z.txt
# METAR_train_part_1/metar.20220910.22Z.txt
# METAR_train_part_1/metar.20221023.21Z.txt
# METAR_train_part_1/metar.20220922.16Z.txt
# METAR_train_part_1/metar.20220904.16Z.txt
# METAR_train_part_1/metar.20221005.21Z.txt
# METAR_train_part_1/metar.20221019.02Z.txt
# METAR_train_part_1/metar.20221009.02Z.txt
# METAR_train_part_1/metar.20221015.21Z.txt
# METAR_train_part_1/metar.20220914.16Z.txt
# METAR_train_part_1/metar.20221024.05Z.txt
# METAR_train_part_1/metar.20220907.06Z.txt
# METAR_train_part_1/metar.20220919.18Z.txt
# METAR_train_part_1/metar.20220909.18Z.txt
# METAR_train_part_1/metar.20220917.06Z.txt
# METAR_train_part_1/metar.20221023.01Z.txt
# METAR_train_part_1/metar.20221003.08Z.txt
# METAR_train_part_1/metar.20221013.08Z.txt
# METAR_train_part_1/metar.20220910.02Z.txt
# METAR_train_part_1/metar.20221020.11Z.txt
# METAR_train_part_1/metar.20220903.12Z.txt
# METAR_train_part_1/metar.20220913.12Z.txt
# METAR_train_part_1/metar.20221010.18Z.txt
# METAR_train_part_1/metar.20220922.20Z.txt
# METAR_train_part_1/metar.20221023.17Z.txt
# METAR_train_part_1/metar.20220910.14Z.txt
# METAR_train_part_1/metar.20221011.23Z.txt
# METAR_train_part_1/metar.20221020.07Z.txt
# METAR_train_part_1/metar.20220913.04Z.txt
# METAR_train_part_1/metar.20220903.04Z.txt
# METAR_train_part_1/metar.20220924.09Z.txt
# METAR_train_part_1/metar.20220908.23Z.txt
# METAR_train_part_1/metar.20220914.00Z.txt
# METAR_train_part_1/metar.20221009.14Z.txt
# METAR_train_part_1/metar.20221019.14Z.txt
# METAR_train_part_1/metar.20220904.00Z.txt
# METAR_train_part_1/metar.20220918.23Z.txt
# METAR_train_part_1/metar.20221024.13Z.txt
# METAR_train_part_1/metar.20220917.10Z.txt
# METAR_train_part_1/metar.20220907.10Z.txt
# METAR_train_part_1/metar.20220902.05Z.txt
# METAR_train_part_1/metar.20220912.05Z.txt
# METAR_train_part_1/metar.20221021.06Z.txt
# METAR_train_part_1/metar.20220901.15Z.txt
# METAR_train_part_1/metar.20220911.15Z.txt
# METAR_train_part_1/metar.20221010.22Z.txt
# METAR_train_part_1/metar.20220923.21Z.txt
# METAR_train_part_1/metar.20221022.16Z.txt
# METAR_train_part_1/metar.20220906.11Z.txt
# METAR_train_part_1/metar.20220916.11Z.txt
# METAR_train_part_1/metar.20221025.12Z.txt
# METAR_train_part_1/metar.20221018.15Z.txt
# METAR_train_part_1/metar.20220919.22Z.txt
# METAR_train_part_1/metar.20220905.01Z.txt
# METAR_train_part_1/metar.20220915.01Z.txt
# METAR_train_part_1/metar.20220909.22Z.txt
# METAR_train_part_1/metar.20221008.15Z.txt
# METAR_train_part_1/metar.20221026.02Z.txt
# METAR_train_part_1/metar.20220916.07Z.txt
# METAR_train_part_1/metar.20220908.19Z.txt
# METAR_train_part_1/metar.20220918.19Z.txt
# METAR_train_part_1/metar.20220906.07Z.txt
# METAR_train_part_1/metar.20221025.04Z.txt
# METAR_train_part_1/metar.20221014.20Z.txt
# METAR_train_part_1/metar.20221008.03Z.txt
# METAR_train_part_1/metar.20220915.17Z.txt
# METAR_train_part_1/metar.20220905.17Z.txt
# METAR_train_part_1/metar.20221018.03Z.txt
# METAR_train_part_1/metar.20221004.20Z.txt
# METAR_train_part_1/metar.20221026.14Z.txt
# METAR_train_part_1/metar.20220912.13Z.txt
# METAR_train_part_1/metar.20221011.19Z.txt
# METAR_train_part_1/metar.20220902.13Z.txt
# METAR_train_part_1/metar.20221021.10Z.txt
# METAR_train_part_1/metar.20221012.09Z.txt
# METAR_train_part_1/metar.20220911.03Z.txt
# METAR_train_part_1/metar.20220901.03Z.txt
# METAR_train_part_1/metar.20221022.00Z.txt
# METAR_train_part_1/metar.20221012.08Z.txt
# METAR_train_part_1/metar.20220911.02Z.txt
# METAR_train_part_1/metar.20220901.02Z.txt
# METAR_train_part_1/metar.20221022.01Z.txt
# METAR_train_part_1/metar.20220912.12Z.txt
# METAR_train_part_1/metar.20221011.18Z.txt
# METAR_train_part_1/metar.20220902.12Z.txt
# METAR_train_part_1/metar.20221021.11Z.txt
# METAR_train_part_1/metar.20221014.21Z.txt
# METAR_train_part_1/metar.20221008.02Z.txt
# METAR_train_part_1/metar.20220915.16Z.txt
# METAR_train_part_1/metar.20220905.16Z.txt
# METAR_train_part_1/metar.20221018.02Z.txt
# METAR_train_part_1/metar.20221004.21Z.txt
# METAR_train_part_1/metar.20221026.15Z.txt
# METAR_train_part_1/metar.20220916.06Z.txt
# METAR_train_part_1/metar.20220908.18Z.txt
# METAR_train_part_1/metar.20220918.18Z.txt
# METAR_train_part_1/metar.20220906.06Z.txt
# METAR_train_part_1/metar.20221025.05Z.txt
# METAR_train_part_1/metar.20221018.14Z.txt
# METAR_train_part_1/metar.20220919.23Z.txt
# METAR_train_part_1/metar.20220905.00Z.txt
# METAR_train_part_1/metar.20220915.00Z.txt
# METAR_train_part_1/metar.20220909.23Z.txt
# METAR_train_part_1/metar.20221008.14Z.txt
# METAR_train_part_1/metar.20221026.03Z.txt
# METAR_train_part_1/metar.20220906.10Z.txt
# METAR_train_part_1/metar.20220916.10Z.txt
# METAR_train_part_1/metar.20221025.13Z.txt
# METAR_train_part_1/metar.20220901.14Z.txt
# METAR_train_part_1/metar.20220911.14Z.txt
# METAR_train_part_1/metar.20221010.23Z.txt
# METAR_train_part_1/metar.20220923.20Z.txt
# METAR_train_part_1/metar.20221022.17Z.txt
# METAR_train_part_1/metar.20220902.04Z.txt
# METAR_train_part_1/metar.20220912.04Z.txt
# METAR_train_part_1/metar.20221021.07Z.txt
# METAR_train_part_1/metar.20221024.12Z.txt
# METAR_train_part_1/metar.20220917.11Z.txt
# METAR_train_part_1/metar.20220907.11Z.txt
# METAR_train_part_1/metar.20220924.08Z.txt
# METAR_train_part_1/metar.20220908.22Z.txt
# METAR_train_part_1/metar.20220914.01Z.txt
# METAR_train_part_1/metar.20221009.15Z.txt
# METAR_train_part_1/metar.20221019.15Z.txt
# METAR_train_part_1/metar.20220904.01Z.txt
# METAR_train_part_1/metar.20220918.22Z.txt
# METAR_train_part_1/metar.20221020.06Z.txt
# METAR_train_part_1/metar.20220913.05Z.txt
# METAR_train_part_1/metar.20220903.05Z.txt
# METAR_train_part_1/metar.20220922.21Z.txt
# METAR_train_part_1/metar.20221023.16Z.txt
# METAR_train_part_1/metar.20220910.15Z.txt
# METAR_train_part_1/metar.20221011.22Z.txt
# METAR_train_part_1/metar.20221020.10Z.txt
# METAR_train_part_1/metar.20220903.13Z.txt
# METAR_train_part_1/metar.20220913.13Z.txt
# METAR_train_part_1/metar.20221010.19Z.txt
# METAR_train_part_1/metar.20221023.00Z.txt
# METAR_train_part_1/metar.20221003.09Z.txt
# METAR_train_part_1/metar.20221013.09Z.txt
# METAR_train_part_1/metar.20220910.03Z.txt
# METAR_train_part_1/metar.20221024.04Z.txt
# METAR_train_part_1/metar.20220907.07Z.txt
# METAR_train_part_1/metar.20220919.19Z.txt
# METAR_train_part_1/metar.20220909.19Z.txt
# METAR_train_part_1/metar.20220917.07Z.txt
# METAR_train_part_1/metar.20220904.17Z.txt
# METAR_train_part_1/metar.20221005.20Z.txt
# METAR_train_part_1/metar.20221019.03Z.txt
# METAR_train_part_1/metar.20221009.03Z.txt
# METAR_train_part_1/metar.20221015.20Z.txt
# METAR_train_part_1/metar.20220914.17Z.txt
# METAR_train_part_1/metar.20221011.14Z.txt
# METAR_train_part_1/metar.20220910.23Z.txt
# METAR_train_part_1/metar.20221023.20Z.txt
# METAR_train_part_1/metar.20220922.17Z.txt
# METAR_train_part_1/metar.20221012.04Z.txt
# METAR_train_part_1/metar.20220921.07Z.txt
# METAR_train_part_1/metar.20220918.14Z.txt
# METAR_train_part_1/metar.20221005.00Z.txt
# METAR_train_part_1/metar.20221019.23Z.txt
# METAR_train_part_1/metar.20221009.23Z.txt
# METAR_train_part_1/metar.20221015.00Z.txt
# METAR_train_part_1/metar.20220908.14Z.txt
# METAR_train_part_1/metar.20221025.09Z.txt
# METAR_train_part_1/metar.20221006.10Z.txt
# METAR_train_part_1/metar.20221016.10Z.txt
# METAR_train_part_1/metar.20221026.19Z.txt
# METAR_train_part_1/metar.20220908.02Z.txt
# METAR_train_part_1/metar.20220914.21Z.txt
# METAR_train_part_1/metar.20221015.16Z.txt
# METAR_train_part_1/metar.20221005.16Z.txt
# METAR_train_part_1/metar.20220904.21Z.txt
# METAR_train_part_1/metar.20220918.02Z.txt
# METAR_train_part_1/metar.20221008.18Z.txt
# METAR_train_part_1/metar.20221016.06Z.txt
# METAR_train_part_1/metar.20221006.06Z.txt
# METAR_train_part_1/metar.20221018.18Z.txt
# METAR_train_part_1/metar.20220912.08Z.txt
# METAR_train_part_1/metar.20221011.02Z.txt
# METAR_train_part_1/metar.20220902.08Z.txt
# METAR_train_part_1/metar.20220922.01Z.txt
# METAR_train_part_1/metar.20221012.12Z.txt
# METAR_train_part_1/metar.20220911.18Z.txt
# METAR_train_part_1/metar.20220901.18Z.txt
# METAR_train_part_1/metar.20220921.11Z.txt
# METAR_train_part_1/metar.20220924.04Z.txt
# METAR_train_part_1/metar.20221019.19Z.txt
# METAR_train_part_1/metar.20221007.07Z.txt
# METAR_train_part_1/metar.20221017.07Z.txt
# METAR_train_part_1/metar.20221009.19Z.txt
# METAR_train_part_1/metar.20221026.23Z.txt
# METAR_train_part_1/metar.20221004.17Z.txt
# METAR_train_part_1/metar.20220919.03Z.txt
# METAR_train_part_1/metar.20220905.20Z.txt
# METAR_train_part_1/metar.20220915.20Z.txt
# METAR_train_part_1/metar.20220909.03Z.txt
# METAR_train_part_1/metar.20221014.17Z.txt
# METAR_train_part_1/metar.20220920.10Z.txt
# METAR_train_part_1/metar.20221003.13Z.txt
# METAR_train_part_1/metar.20221013.13Z.txt
# METAR_train_part_1/metar.20220910.19Z.txt
# METAR_train_part_1/metar.20220923.00Z.txt
# METAR_train_part_1/metar.20220903.09Z.txt
# METAR_train_part_1/metar.20220913.09Z.txt
# METAR_train_part_1/metar.20221010.03Z.txt
# METAR_train_part_1/metar.20220920.06Z.txt
# METAR_train_part_1/metar.20221013.05Z.txt
# METAR_train_part_1/metar.20221003.05Z.txt
# METAR_train_part_1/metar.20221022.21Z.txt
# ...
# 230515_230607/06/07/2023_06_07_02_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_00_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_11_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_13_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_14_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_07_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_08_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_20_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_19_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_01_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_12_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_12_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_01_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_14_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_20_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_18_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_23_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_21_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_02_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_11_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_09_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_23_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_18_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_17_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_04_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_01_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_03_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_12_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_10_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_08_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_14_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_16_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_07_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_05_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_15_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_06_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_21_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_00_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_13_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_20_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_22_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_19_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_19_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_08_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_22_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_05_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_16_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_10_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_03_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_09_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_04_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_06_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_17_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_15_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_11_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_13_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_02_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/07/2023_06_07_00_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_17_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_15_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_04_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_06_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_09_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_02_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_11_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_13_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_16_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_05_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_08_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_22_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_19_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_03_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_10_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_19_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_20_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_22_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_21_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_06_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_15_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_13_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_00_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_12_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_10_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_01_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_03_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_07_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_05_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_14_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_16_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_08_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_11_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_02_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_04_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_17_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_18_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_09_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_23_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_23_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_21_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_18_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_01_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_12_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_20_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_14_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_07_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_19_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_08_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_20_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_07_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_14_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_12_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_01_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_18_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_04_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_06_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_17_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_15_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_11_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_13_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_02_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_00_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_17_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_04_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_23_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_02_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_11_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_20_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_22_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_08_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_00_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_13_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_09_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_21_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_18_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_15_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_06_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_03_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_12_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_10_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_19_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_14_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_16_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_07_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_05_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_10_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_03_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_05_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_16_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_22_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_23_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_21_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/01/2023_06_01_09_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_22_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_20_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_08_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_17_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_04_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_23_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_02_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_11_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_18_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_04_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_15_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_17_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_13_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_11_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_00_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_02_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_19_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_08_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_20_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_07_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_14_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_12_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_01_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_21_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_23_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_09_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_10_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_03_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_05_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_16_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_22_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_03_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_01_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_10_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_12_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_19_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_16_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_14_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_05_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_07_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_00_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_13_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_09_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_21_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_18_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_15_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_06_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_21_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_06_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_15_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_13_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_00_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_19_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_22_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_20_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_16_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_05_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_08_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_22_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_19_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_03_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_10_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_15_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_17_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_06_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_04_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_09_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_00_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_02_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_13_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_11_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_01_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_12_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_20_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_14_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_07_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_21_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_23_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_18_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_11_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_02_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_04_15_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_18_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_09_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_23_00_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_10_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_12_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_03_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_01_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_05_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_07_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_16_45_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_14_30_GMT.Forecast.h5.CWAM.h5.bz2
# 230515_230607/06/06/2023_06_06_08_15_GMT.Forecast.h5.CWAM.h5.bz2
